# %%
# !pip install pandas

# %% [markdown]
# ### HOW TO READ A FILE

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 68D7-27A6
#
#  Directory of C:\hello world\ba
#
# 07/23/2023  05:31 PM    <DIR>          .
# 07/23/2023  05:26 PM    <DIR>          ..
# 07/23/2023  05:21 PM    <DIR>          .ipynb_checkpoints
# 07/23/2023  05:22 PM               589 DATA ANALYSIS - WRK1.ipynb
# 07/23/2023  05:13 PM           237,273 Data Analysis_Introduction_and_Implementation note1.ipynb
# 07/19/2023  10:44 AM                59 demo1.csv
# 07/23/2023  05:31 PM    <DIR>          pandas_docs (1)
# 07/23/2023  05:29 PM        20,471,963 pandas_docs (1).zip
#                4 File(s)     20,709,884 bytes
#                4 Dir(s)  184,334,069,760 bytes free

# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 68D7-27A6
#
#  Directory of C:\hello world\ba
#
# 07/23/2023  05:35 PM    <DIR>          .
# 07/23/2023  05:26 PM    <DIR>          ..
# 07/23/2023  05:21 PM    <DIR>          .ipynb_checkpoints
# 07/23/2023  05:35 PM             3,791 DATA ANALYSIS - WRK1.ipynb
# 07/23/2023  05:13 PM           237,273 Data Analysis_Introduction_and_Implementation note1.ipynb
# 07/19/2023  10:44 AM                59 demo1.csv
# 07/23/2023  05:31 PM    <DIR>          pandas_docs (1)
# 07/23/2023  05:29 PM        20,471,963 pandas_docs (1).zip
#                4 File(s)     20,713,086 bytes
#                4 Dir(s)  184,334,032,896 bytes free

# %%
pd.read_csv('demo1.csv')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
pd.read_csv('C:\hello world\ba\pandas_docs (1)\demo4.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pd.read_csv('C:\hello world\ba\pandas_docs (1)\demo4.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
pd.read_csv('C:\\hello world\\ba\\pandas_docs (1)\\demo4.csv')
# Out:
#                                                                  # hey!
# a                                                  b   c   d    message
# # just wanted to make things more understandable   NaN NaN NaN      NaN
# # do you have enough skills to become a data sc... NaN NaN NaN      NaN
# 1                                                  2   3   4      hello
# 5                                                  6   7   8      world
# 9                                                  10  11  12       foo

# %%
pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo4.csv')
# Out:
#                                                                  # hey!
# a                                                  b   c   d    message
# # just wanted to make things more understandable   NaN NaN NaN      NaN
# # do you have enough skills to become a data sc... NaN NaN NaN      NaN
# 1                                                  2   3   4      hello
# 5                                                  6   7   8      world
# 9                                                  10  11  12       foo

# %%
pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\titan.csv')
# Out:
#      Unnamed: 0                                               Name  Survived
# 0             0                            Braund, Mr. Owen Harris         0
# 1             1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2             2                             Heikkinen, Miss. Laina         1
# 3             3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4             4                           Allen, Mr. William Henry         0
# ..          ...                                                ...       ...
# 886         886                              Montvila, Rev. Juozas         0
# 887         887                       Graham, Miss. Margaret Edith         1
# 888         888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889         889                              Behr, Mr. Karl Howell         1
# 890         890                                Dooley, Mr. Patrick         0
#
# [891 rows x 3 columns]

# %%
pd.read_csv('final.csv')
# Out:
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
import pandas as pd

# %%
pd.read_csv('./test_folder/demo4.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd.read_csv('.//test_folder//demo4.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
data=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo1.csv')
data
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %% [markdown]
# ### CSV TO TSV

# %%
data1=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\test.tsv',sep="\t")
data1
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
data1=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\test.tsv')
data1
# Out:
#                        test\t test\ttest\ttest\ttest
# 0   Magnus\tMagnus\tMagnus\tMagnus\tMagnus\tMagnus\t
# 1  Carlsen\tCarlsen\tCarlsen\tCarlsen\tCarlsen\tC...

# %% [markdown]
# ### TSV TO TSV

# %%
# !pip install pandas

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 68D7-27A6
#
#  Directory of C:\hello world\ba
#
# 07/23/2023  08:06 PM    <DIR>          .
# 07/23/2023  05:26 PM    <DIR>          ..
# 07/23/2023  05:21 PM    <DIR>          .ipynb_checkpoints
# 07/23/2023  08:06 PM            52,768 DATA ANALYSIS - WRK1.ipynb
# 07/23/2023  05:55 PM           237,273 Data Analysis_Introduction_and_Implementation note1.ipynb
# 07/19/2023  10:44 AM                59 demo1.csv
# 07/23/2023  05:31 PM             2,681 final.csv
# 07/23/2023  05:45 PM    <DIR>          pandas_docs (1)
# 07/23/2023  05:29 PM        20,471,963 pandas_docs (1).zip
#                5 File(s)     20,764,744 bytes
#                4 Dir(s)  184,319,463,424 bytes free

# %%
import pandas as pd

# %%
data2=pd.read_table(r'C:\hello world\ba\pandas_docs (1)\test.tsv')
data2
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
data2=pd.read_table('test.tsv')
data2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data2=pd.read_table('test.tsv')
#       2 data2
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
pand=pd.read_table(r'C:\hello world\ba\pandas_docs (1)\demo2.csv')
pand
# Out:
#      1,2,3,4,hello
# 0    5,6,7,8,world
# 1  9,10,11,12,file

# %%
pand=pd.read_table(r'C:\hello world\ba\pandas_docs (1)\demo2.csv',sep=',')
pand
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12   file

# %%
type(pand)
# Out:
# pandas.core.frame.DataFrame

# %%
pand.loc[0]
# Out:
# 1            5
# 2            6
# 3            7
# 4            8
# hello    world
# Name: 0, dtype: object

# %% [markdown]
# ### tsv to csv

# %%
data3=pd.read_table(r'C:\hello world\ba\pandas_docs (1)\demo3.csv')
data3
# Out:
#                A         B         C
# 0  aaa -0.264438 -1.026059 -0.619500
# 1  bbb  0.927272  0.302904 -0.032399
# 2  ccc -0.264273 -0.386314 -0.217601
# 3  ddd -0.871858 -0.348382  1.100491

# %%
data3=pd.read_table(r'C:\hello world\ba\pandas_docs (1)\demo3.csv',sep='-')
data3
# Out:
#                                                                   A         B         C
# aaa                      0.264438 1.026059                                     0.619500
# bbb  0.927272  0.302904  0.032399 NaN                                               NaN
# ccc                      0.264273 0.386314                                     0.217601
# ddd                      0.871858 0.348382  1.100491                                NaN

# %%
type(data3)
# Out:
# pandas.core.frame.DataFrame

# %%
data3.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data4=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo6.csv')
data4
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
data4=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo6.csv',usecols=['one','four','key'])
data4
# Out:
#            one      four key
# 0     0.467976 -1.824726   L
# 1    -0.358893 -0.200638   B
# 2    -0.501840 -0.057688   G
# 3     0.204886 -0.982404   R
# 4     0.354628 -0.837063   Q
# ...        ...       ...  ..
# 9995  2.311896 -0.515821   L
# 9996 -0.479893 -0.646038   E
# 9997  0.523331  1.093156   K
# 9998 -0.362559  0.887292   G
# 9999 -0.096376 -0.573315   0
#
# [10000 rows x 3 columns]

# %%
data4=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo7.csv')
data4
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3

# %%
data4=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo7.csv',usecols=['a'])
data4
# Out:
#    a
# 0  1
# 1  1

# %%
data5=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo4.csv')
data5
# Out:
#                                                                  # hey!
# a                                                  b   c   d    message
# # just wanted to make things more understandable   NaN NaN NaN      NaN
# # do you have enough skills to become a data sc... NaN NaN NaN      NaN
# 1                                                  2   3   4      hello
# 5                                                  6   7   8      world
# 9                                                  10  11  12       foo

# %%
data5=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo4.csv', skiprows=[0,2,3])
data5
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# ## giving headings using "names" option

# %%
df1=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo1.csv')
df1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
#to give headings of  table using names option

# %%
df1=pd.read_csv(r'C:\hello world\ba\pandas_docs (1)\demo1.csv',names=['one','two','three','four','five'])
df1
# Out:
#   one two three four     five
# 0   a   b     c    d  message
# 1   1   2     3    4    hello
# 2   5   6     7    8    world
# 3   9  10    11   12     file

# %% [markdown]
# ### reading excel

# %%
df2=pd.read_excel(r'C:\hello world\ba\pandas_docs (1)\demo1.xlsx')
df2
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
df2=pd.read_excel(r'C:\hello world\ba\pandas_docs (1)\demo1.xlsx',index_col=[0])
df2
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df2=pd.read_excel(r'C:\hello world\ba\pandas_docs (1)\demo1.xlsx',sheet_name='sheet_name')
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df2=pd.read_excel(r'C:\hello world\ba\pandas_docs (1)\demo1.xlsx',sheet_name='sheet_name')
#       2 df2
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ### HTML FILE READINGS

# %%
url="https://www.basketball-reference.com/players/c/collijo01.html"

# %%
bask=pd.read_html(url)
bask
# Out:
# [    Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
#  0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
#  1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
#  2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
#  3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
#  4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
#  5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
#  6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#     DRB   TRB  AST  STL  BLK  TOV   PF   PTS
#  0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
#  1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
#  2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
#  3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
#  4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
#  5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# ...

# %%
bask1=bask[0]
bask1
# Out:
#     Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
# 0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
# 1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
# 2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
# 3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
# 4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
# 5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
# 6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
# 5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# 6  5.8   8.0  1.5  0.6  1.0  1.4  3.1  15.8
#
# ...

# %%
bask2=bask[3]
bask2
# Out:
#     Season   Age   Tm   Lg  Pos    G   GS     MP    FG   FGA  ...    FT%  ORB  \
# 0  2017-18  20.0  ATL  NBA   PF   74   26   1785   314   545  ...  0.715  176
# 1  2018-19  21.0  ATL  NBA   PF   61   59   1829   465   831  ...  0.763  219
# 2  2019-20  22.0  ATL  NBA   PF   41   41   1363   353   605  ...  0.800  116
# 3  2020-21  23.0  ATL  NBA   PF   63   63   1848   429   771  ...  0.833  118
# 4  2021-22  24.0  ATL  NBA   PF   54   53   1663   339   644  ...  0.793   93
# 5  2022-23  25.0  ATL  NBA   PF   71   71   2130   359   707  ...  0.803   77
# 6   Career   NaN  NaN  NBA  NaN  364  313  10618  2259  4103  ...  0.783  799
#
#     DRB   TRB  AST  STL  BLK  TOV    PF   PTS
# 0   365   541   98   47   80  105   215   777
# 1   376   595  121   22   39  120   199  1188
# 2   300   416   60   31   66   75   138   885
# 3   349   467   78   34   63   84   193  1111
# 4   329   422   98   33   56   60   164   876
# 5   385   462   85   42   73   79   220   931
# ...

# %%
bask_last=bask[-1]
bask_last
# Out:
#     Season   Age   Tm   Lg  Pos   G   MP   PER    TS%   3PAr  ...  \
# 0  2020-21  23.0  ATL  NBA   PF  18  576  15.3  0.632  0.308  ...
# 1  2021-22  24.0  ATL  NBA   PF   5  122  10.7  0.541  0.282  ...
# 2  2022-23  25.0  ATL  NBA   PF   6  164  10.1  0.543  0.533  ...
# 3   Career   NaN  NaN  NBA  NaN  29  862  13.7  0.601  0.352  ...
#
#    Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0          NaN  0.9  0.8  1.7  0.140          NaN   1.1  -0.2  0.9   0.4
# 1          NaN  0.0  0.1  0.1  0.034          NaN  -0.8   0.0 -0.9   0.0
# 2          NaN  0.0  0.0  0.0 -0.007          NaN  -2.3  -1.1 -3.5  -0.1
# 3          NaN  0.8  0.9  1.7  0.097          NaN   0.2  -0.4 -0.2   0.4
#
# [4 rows x 29 columns]

# %%
bask1.head()
# Out:
#     Season   Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  DRB  \
# 0  2017-18  20.0  ATL  NBA  PF  74  26  24.1  4.2   7.4  ...  0.715  2.4  4.9
# 1  2018-19  21.0  ATL  NBA  PF  61  59  30.0  7.6  13.6  ...  0.763  3.6  6.2
# 2  2019-20  22.0  ATL  NBA  PF  41  41  33.2  8.6  14.8  ...  0.800  2.8  7.3
# 3  2020-21  23.0  ATL  NBA  PF  63  63  29.3  6.8  12.2  ...  0.833  1.9  5.5
# 4  2021-22  24.0  ATL  NBA  PF  54  53  30.8  6.3  11.9  ...  0.793  1.7  6.1
#
#     TRB  AST  STL  BLK  TOV   PF   PTS
# 0   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4   7.8  1.8  0.6  1.0  1.1  3.0  16.2
#
# [5 rows x 30 columns]

# %%
import pandas as pd

# %%
bask1.head(3)
# Out:
#     Season   Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  DRB  \
# 0  2017-18  20.0  ATL  NBA  PF  74  26  24.1  4.2   7.4  ...  0.715  2.4  4.9
# 1  2018-19  21.0  ATL  NBA  PF  61  59  30.0  7.6  13.6  ...  0.763  3.6  6.2
# 2  2019-20  22.0  ATL  NBA  PF  41  41  33.2  8.6  14.8  ...  0.800  2.8  7.3
#
#     TRB  AST  STL  BLK  TOV   PF   PTS
# 0   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  10.1  1.5  0.8  1.6  1.8  3.4  21.6
#
# [3 rows x 30 columns]

# %%
data_git = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
data_git
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_git.shape
# Out:
# (891, 12)

# %%
data_git.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data_git.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
data_git.size
# Out:
# 10692

# %%
prssr=pd.read_csv('https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/blood_pressure.csv')
prssr
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %%
prssr.shape
# Out:
# (120, 5)

# %%
prssr.columns
# Out:
# Index(['patient', 'sex', 'agegrp', 'bp_before', 'bp_after'], dtype='object')

# %%
prssr.head(7)
# Out:
#    patient   sex agegrp  bp_before  bp_after
# 0        1  Male  30-45        143       153
# 1        2  Male  30-45        163       170
# 2        3  Male  30-45        153       168
# 3        4  Male  30-45        153       142
# 4        5  Male  30-45        146       141
# 5        6  Male  30-45        150       147
# 6        7  Male  30-45        148       133

# %%
prssr.size
# Out:
# 600

# %% [markdown]
# #### html

# %%
htm=pd.read_html(r"file:///C:/Users/codem/Downloads/404.html")
htm
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\lib\urllib\request.py:1505, in FileHandler.open_local_file(self, req)
#    1504 try:
# -> 1505     stats = os.stat(localfile)
#    1506     size = stats.st_size
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\codem\\Downloads\\404.html'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 htm=pd.read_html(r"file:///C:/Users/codem/Downloads/404.html")
#       2 htm
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
writable_file=titanic[['Survived','Name','Age','Embarked']]

# %%
writable_file.to_csv("writed_file.csv")

# %%
writable_file.to_excel("write_excel.xlsx")

# %% [markdown]
# ## assignment

# %% [markdown]
# ### 2-Create a data frame which contains name and age of workshop participants(random age)-both dictionary and list

# %%
import random
participants_dict = {
    'Name': ['ram', 'theja', 'hash','hridya', 'nida'],
    'Age': [random.randint(20, 60) for _ in range(5)]
}
df4 = pd.DataFrame(participants_dict)
df4
# Out:
#      Name  Age
# 0     ram   21
# 1   theja   53
# 2    hash   59
# 3  hridya   57
# 4    nida   23
